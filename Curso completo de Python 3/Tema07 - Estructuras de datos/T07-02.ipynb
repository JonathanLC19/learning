# %% [markdown]
# # Ejercicio
#
# Tenemos un diccionario con 5 claves: `Math`, `English`, `History`, `Science`, `IT`. Cada clave contiene una lista de tamaño 3, donde cada una de esas entradas se corresponde con una nota de 0 a 10. El usuario va a ser quien introduzca esas notas por teclado. Finalmente, para cada clave, mostraremos la media de las 3 notas.
#
# PISTA: Necesitarás la función `sum()`.

# %%
notas = {"Math": [],
         "English": [],
         "History": [],
         "Science": [],
         "IT": []
        }
for key in notas:
    print("****", key, "****")
    for i in range(1, 4):
        notas[key].append(int(input("Nota Q{}: ".format(i))))

print("\n Notas medias: \n")

for key, val in notas.items():
    print(key, ":", sum(val)/len(val))
# Out:
# **** Math ****
# Nota Q1: 9
# Nota Q2: 9
# Nota Q3: 8
# **** English ****
# Nota Q1: 5
# Nota Q2: 6
# Nota Q3: 7
# **** History ****
# Nota Q1: 8
# Nota Q2: 9
# Nota Q3: 9
# **** Science ****
# Nota Q1: 7
# Nota Q2: 8
# Nota Q3: 8
# **** IT ****
# Nota Q1: 9
# Nota Q2: 10
# Nota Q3: 9
#
#  Notas medias:
#
# Math : 8.666666666666666
# English : 6.0
# History : 8.666666666666666
# Science : 7.666666666666667
# IT : 9.333333333333334

# %%
subjects = {"Math": [],
            "English": [],
            "History": [],
            "Science": [],
            "IT": []}

for key in subjects:
  print("===", key, "===")
  for i in range(1, 4):
    subjects[key].append(int(input("Nota trimestre {} ".format(i))))

print("\n Medias por asignatura:")
for key, val in subjects.items():
  print(key, ":", sum(val)/len(val))
# Out:
# === Math ===
# Nota trimestre 1 7
# Nota trimestre 2 7
# Nota trimestre 3 7
# === English ===
# Nota trimestre 1 7
# Nota trimestre 2 7
# Nota trimestre 3 7
# === History ===
# Nota trimestre 1 6
# Nota trimestre 2 6
# Nota trimestre 3 6
# === Science ===
# Nota trimestre 1 5
# Nota trimestre 2 5
# Nota trimestre 3 5
# === IT ===
# Nota trimestre 1 8
# Nota trimestre 2 8
# Nota trimestre 3 8
#
#  Medias por asignatura:
# Math : 7.0
# English : 7.0
# History : 6.0
# Science : 5.0
# IT : 8.0
